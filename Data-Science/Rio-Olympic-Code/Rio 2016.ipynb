# %%
import pandas as pd

data = pd.read_csv("rio_2016.csv")
data
# Out:
#               id                      name nationality     sex date_of_birth  \
# 0      736041664            A Jesus Garcia         ESP    male    1969-10-17
# 1      532037425                A Lam Shin         KOR  female    1986-09-23
# 2      435962603               Aaron Brown         CAN    male    1992-05-27
# 3      521041435                Aaron Cook         MDA    male    1991-01-02
# 4       33922579                Aaron Gate         NZL    male    1990-11-26
# 5      173071782               Aaron Royle         AUS    male    1990-01-26
# 6      266237702             Aaron Russell         USA    male    1993-06-04
# 7      382571888             Aaron Younger         AUS    male    1991-09-25
# 8       87689776       Aauri Lorena Bokesa         ESP  female    1988-12-14
# 9      997877719           Ababel Yeshaneh         ETH  female    1991-07-22
# 10     343694681               Abadi Hadis         ETH    male    1997-11-06
# ...

# %%
data['weight'] = data['weight'] * 2.20462

# %%
data['height'] = data['height'] * 3.28084

# %%
import seaborn as sns
# %matplotlib inline
#Plot the Regression for Height vs Weight
sns.regplot(x=data["weight"], y=data["height"]).set_title("All Sports")
# Out:
# Text(0.5,1,'All Sports')

# %%
athletics = data.loc[data['sport'] == "athletics"]
gymnastics = data.loc[data['sport'] == "gymnastics"]
volleyball = data.loc[data['sport'] == "volleyball"]
aquatics = data.loc[data['sport'] == "aquatics"]
weightlift = data.loc[data['sport'] == "weightlifting"]

gymnasticsW = gymnastics.loc[gymnastics['gold'] == 1]
gymnasticsW = gymnastics.loc[gymnastics['silver'] == 1]
gymnasticsW = gymnastics.loc[gymnastics['bronze'] == 1]

volleyballW = volleyball.loc[volleyball['gold'] == 1]
volleyballW = volleyball.loc[volleyball['silver'] == 1]
volleyballW = volleyball.loc[volleyball['bronze'] == 1]

aquaticsW = aquatics.loc[aquatics['gold'] == 1]
aquaticsW = aquatics.loc[aquatics['silver'] == 1]
aquaticsW = aquatics.loc[aquatics['bronze'] == 1]

volleyballW.describe()
# Out:
#                  id     height      weight  gold  silver  bronze
# count  2.800000e+01  28.000000   28.000000  28.0    28.0    28.0
# mean   4.380326e+08   6.310930  182.196096   0.0     0.0     1.0
# std    2.598738e+08   0.294832   21.925138   0.0     0.0     0.0
# min    9.514544e+06   5.577428  145.504920   0.0     0.0     1.0
# 25%    2.190014e+08   6.167979  165.346500   0.0     0.0     1.0
# 50%    4.573137e+08   6.299213  175.267290   0.0     0.0     1.0
# 75%    6.547354e+08   6.520669  196.762335   0.0     0.0     1.0
# max    8.930658e+08   6.791339  231.485100   0.0     0.0     1.0

# %%
sns.regplot(x=athletics["weight"], y=athletics["height"]).set_title("Athletics")
# Out:
# Text(0.5,1,'Athletics')

# %%
sns.regplot(x=gymnastics["weight"], y=gymnastics["height"]).set_title("Gymnastics")
# Out:
# Text(0.5,1,'Gymnastics')

# %%
sns.regplot(x=aquatics["weight"], y=aquatics["height"]).set_title("Aquatics")
# Out:
# Text(0.5,1,'Aquatics')

# %%
sns.regplot(x=volleyball["weight"], y=volleyball["height"]).set_title("Volleyball")
# Out:
# Text(0.5,1,'Volleyball')

# %%
sns.regplot(x=weightlift["weight"], y=weightlift["height"]).set_title("Weightlifting")
# Out:
# Text(0.5,1,'Weightlifting')

# %%
# Out:
#                  id       height       weight         gold       silver  \
# count  1.445000e+03  1396.000000  1399.000000  1445.000000  1445.000000
# mean   4.997725e+08     5.867251   159.397650     0.083045     0.077509
# std    2.864110e+08     0.361777    31.597648     0.347164     0.294595
# min    3.545330e+05     4.691601    85.980180     0.000000     0.000000
# 25%    2.488850e+08     5.577428   134.481820     0.000000     0.000000
# 50%    5.008596e+08     5.839895   154.323400     0.000000     0.000000
# 75%    7.465760e+08     6.135171   180.778840     0.000000     0.000000
# max    9.987105e+08     7.250656   286.600600     5.000000     2.000000
#
#             bronze
# count  1445.000000
# mean      0.073356
# std       0.283704
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       2.000000

# %%
data
# Out:
#               id                      name nationality     sex date_of_birth  \
# 0      736041664            A Jesus Garcia         ESP    male    1969-10-17
# 1      532037425                A Lam Shin         KOR  female    1986-09-23
# 2      435962603               Aaron Brown         CAN    male    1992-05-27
# 3      521041435                Aaron Cook         MDA    male    1991-01-02
# 4       33922579                Aaron Gate         NZL    male    1990-11-26
# 5      173071782               Aaron Royle         AUS    male    1990-01-26
# 6      266237702             Aaron Russell         USA    male    1993-06-04
# 7      382571888             Aaron Younger         AUS    male    1991-09-25
# 8       87689776       Aauri Lorena Bokesa         ESP  female    1988-12-14
# 9      997877719           Ababel Yeshaneh         ETH  female    1991-07-22
# 10     343694681               Abadi Hadis         ETH    male    1997-11-06
# ...

# %%
volleyball.describe()
# Out:
#                  id      height      weight        gold      silver  \
# count  3.840000e+02  383.000000  382.000000  384.000000  384.000000
# mean   4.844270e+08    6.222203  176.594679    0.072917    0.070312
# std    2.997636e+08    0.336432   26.648823    0.260339    0.256006
# min    1.610593e+06    5.216536  114.640240    0.000000    0.000000
# 25%    2.072330e+08    6.003937  156.528020    0.000000    0.000000
# 50%    4.879827e+08    6.233596  174.164980    0.000000    0.000000
# 75%    7.319181e+08    6.463255  196.211180    0.000000    0.000000
# max    9.995806e+08    6.922572  253.531300    1.000000    1.000000
#
#            bronze
# count  384.000000
# mean     0.072917
# std      0.260339
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000
